# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.preprocessing import LabelEncoder
import copy

# %%
data1=pd.read_csv("carsales.csv")

# %%
data1
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data1.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
data1.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data1.shape
# Out:
# (157, 16)

# %%
data1.size
# Out:
# 2512

# %%
data1.loc[:,'Model']=np.nan

# %%
data1
# Out:
#     Manufacturer  Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0          Acura    NaN              16.919               16.360    Passenger
# 1          Acura    NaN              39.384               19.875    Passenger
# 2          Acura    NaN              14.114               18.225    Passenger
# 3          Acura    NaN               8.588               29.725    Passenger
# 4           Audi    NaN              20.397               22.255    Passenger
# ..           ...    ...                 ...                  ...          ...
# 152        Volvo    NaN               3.545                  NaN    Passenger
# 153        Volvo    NaN              15.245                  NaN    Passenger
# 154        Volvo    NaN              17.531                  NaN    Passenger
# 155        Volvo    NaN               3.493                  NaN    Passenger
# 156        Volvo    NaN              18.969                  NaN    Passenger
#
# ...

# %%
data1.Model
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 152   NaN
# 153   NaN
# 154   NaN
# 155   NaN
# 156   NaN
# Name: Model, Length: 157, dtype: float64

# %%
data1['Model'].fillna(100,inplace=True)

# %%
data1
# Out:
#     Manufacturer  Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0          Acura  100.0              16.919               16.360    Passenger
# 1          Acura  100.0              39.384               19.875    Passenger
# 2          Acura  100.0              14.114               18.225    Passenger
# 3          Acura  100.0               8.588               29.725    Passenger
# 4           Audi  100.0              20.397               22.255    Passenger
# ..           ...    ...                 ...                  ...          ...
# 152        Volvo  100.0               3.545                  NaN    Passenger
# 153        Volvo  100.0              15.245                  NaN    Passenger
# 154        Volvo  100.0              17.531                  NaN    Passenger
# 155        Volvo  100.0               3.493                  NaN    Passenger
# 156        Volvo  100.0              18.969                  NaN    Passenger
#
# ...

# %%
data1.drop(['Model'],axis=1)
# Out:
#     Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0          Acura              16.919               16.360    Passenger
# 1          Acura              39.384               19.875    Passenger
# 2          Acura              14.114               18.225    Passenger
# 3          Acura               8.588               29.725    Passenger
# 4           Audi              20.397               22.255    Passenger
# ..           ...                 ...                  ...          ...
# 152        Volvo               3.545                  NaN    Passenger
# 153        Volvo              15.245                  NaN    Passenger
# 154        Volvo              17.531                  NaN    Passenger
# 155        Volvo               3.493                  NaN    Passenger
# 156        Volvo              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
plt.bar(data1.Engine_size,data1.Length,color='b')
# Out:
# <BarContainer object of 157 artists>

# %%
data1.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
data1=data1.dropna()

# %%
data1
# Out:
#     Manufacturer  Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0          Acura  100.0              16.919               16.360    Passenger
# 1          Acura  100.0              39.384               19.875    Passenger
# 3          Acura  100.0               8.588               29.725    Passenger
# 4           Audi  100.0              20.397               22.255    Passenger
# 5           Audi  100.0              18.780               23.555    Passenger
# ..           ...    ...                 ...                  ...          ...
# 145   Volkswagen  100.0               9.761               11.425    Passenger
# 146   Volkswagen  100.0              83.721               13.240    Passenger
# 147   Volkswagen  100.0              51.102               16.725    Passenger
# 148   Volkswagen  100.0               9.569               16.575    Passenger
# 149   Volkswagen  100.0               5.596               13.760    Passenger
#
# ...

# %%
data1.set_index('Manufacturer')
# Out:
#               Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Manufacturer
# Acura         100.0              16.919               16.360    Passenger
# Acura         100.0              39.384               19.875    Passenger
# Acura         100.0               8.588               29.725    Passenger
# Audi          100.0              20.397               22.255    Passenger
# Audi          100.0              18.780               23.555    Passenger
# ...             ...                 ...                  ...          ...
# Volkswagen    100.0               9.761               11.425    Passenger
# Volkswagen    100.0              83.721               13.240    Passenger
# Volkswagen    100.0              51.102               16.725    Passenger
# Volkswagen    100.0               9.569               16.575    Passenger
# Volkswagen    100.0               5.596               13.760    Passenger
#
# ...

# %%
sns.scatterplot(data1.Price_in_thousands,data1.Sales_in_thousands,color='hotpink')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price_in_thousands', ylabel='Sales_in_thousands'>

# %%
H0='Price is equal to sales' #null hypothesis
Ha='Price is not equal to sales' #alternate hypothesis
x=np.array(data1.Price_in_thousands)
y=np.array(data1.Sales_in_thousands)
t,p_value=stats.ttest_ind(x,y,axis=0)
if p_value<0.5:
    print(f'{Ha} as the p value {p_value} is less than 0.05')
else:
    print(f'{H0} as the p value {p_value} is greater than 0.05')
# Out:
# Price is not equal to sales as the p value 4.5928792729945385e-06 is less than 0.05
